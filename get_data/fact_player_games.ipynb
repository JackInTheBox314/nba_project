# %%
import nba_api.stats.endpoints as stats

# %%
df = stats.leaguegamefinder.LeagueGameFinder('P', season_nullable='2024-25').get_data_frames()[0]
df
# Out:
#       SEASON_ID  PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0         42024    1642349    Ajay Mitchell  1610612760               OKC
# 1         42024    1642277    Johnny Furphy  1610612754               IND
# 2         42024    1641794     Dillon Jones  1610612760               OKC
# 3         42024    1631096    Chet Holmgren  1610612760               OKC
# 4         42024    1628396     Tony Bradley  1610612754               IND
# ...         ...        ...              ...         ...               ...
# 29995     12024    1630171      Isaac Okoro  1610612739               CLE
# 29996     12024    1641727  Dariq Whitehead  1610612751               BKN
# 29997     12024    1631245  Quenton Jackson  1610612754               IND
# 29998     12024    1641706   Brandon Miller  1610612766               CHA
# 29999     12024    1631243   Mouhamed Gueye  1610612737               ATL
#
#                    TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  ...  \
# 0      Oklahoma City Thunder  0042400407  2025-06-22  OKC vs. IND  W  ...
# 1             Indiana Pacers  0042400407  2025-06-22    IND @ OKC  L  ...
# 2      Oklahoma City Thunder  0042400407  2025-06-22  OKC vs. IND  W  ...
# 3      Oklahoma City Thunder  0042400407  2025-06-22  OKC vs. IND  W  ...
# 4             Indiana Pacers  0042400407  2025-06-22    IND @ OKC  L  ...
# ...                      ...         ...         ...          ... ..  ...
# 29995    Cleveland Cavaliers  0012400016  2024-10-08  CLE vs. CHI  L  ...
# 29996          Brooklyn Nets  0012400019  2024-10-08    BKN @ LAC  L  ...
# 29997         Indiana Pacers  0012400018  2024-10-08    IND @ ATL  L  ...
# 29998      Charlotte Hornets  0012400015  2024-10-08  CHA vs. MIA  W  ...
# 29999          Atlanta Hawks  0012400018  2024-10-08  ATL vs. IND  W  ...
#
#        FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0         NaN     0     0    0    0    0    0    1   0          -4
# 1         NaN     0     0    0    0    0    0    0   0           4
# 2         NaN     0     0    0    0    0    0    0   1          -4
# 3       0.625     2     6    8    0    1    5    0   3          10
# 4       1.000     0     1    1    0    0    0    1   2          -2
# ...       ...   ...   ...  ...  ...  ...  ...  ...  ..         ...
# 29995   0.500     0     0    0    0    0    0    1   0          -5
# 29996     NaN     0     1    1    0    0    0    1   1          -9
# 29997   1.000     2     2    4    4    0    1    1   3          -2
# 29998   1.000     0     4    4    2    0    2    1   2         -13
# 29999   0.500     0     0    0    2    2    0    1   3           0
#
# [30000 rows x 30 columns]

# %%
df.to_csv('../data/fact_player_games.csv', index=False)
