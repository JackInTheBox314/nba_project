# %%
import nba_api.stats.endpoints as stats

# %%
df = stats.leaguegamefinder.LeagueGameFinder('P', season_nullable='2024-25').get_data_frames()[0]
df
# Out:
#       SEASON_ID  PLAYER_ID         PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0         42024    1628396        Tony Bradley  1610612754               IND
# 1         42024    1631097  Bennedict Mathurin  1610612754               IND
# 2         42024    1630174       Aaron Nesmith  1610612754               IND
# 3         42024    1630598       Aaron Wiggins  1610612760               OKC
# 4         42024    1627936         Alex Caruso  1610612760               OKC
# ...         ...        ...                 ...         ...               ...
# 29995     12024     202710    Jimmy Butler III  1610612748               MIA
# 29996     12024    1631204       Marcus Sasser  1610612765               DET
# 29997     12024     203486       Mason Plumlee  1610612756               PHX
# 29998     12024    1641787     Tosan Evbuomwan  1610612765               DET
# 29999     12024    1642345        Oso Ighodaro  1610612756               PHX
#
# ...

# %%
df.to_csv('../data/fact_player_games.csv', index=False)
