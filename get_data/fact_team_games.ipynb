# %%
import nba_api.stats.endpoints as stats

# %%
df = stats.leaguegamefinder.LeagueGameFinder('T', season_nullable='2024-25').get_data_frames()[0]
df
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        42024  1610612754               IND          Indiana Pacers
# 1        42024  1610612760               OKC   Oklahoma City Thunder
# 2        42024  1610612754               IND          Indiana Pacers
# 3        42024  1610612760               OKC   Oklahoma City Thunder
# 4        42024  1610612760               OKC   Oklahoma City Thunder
# ...        ...         ...               ...                     ...
# 2797     12024  1610612747               LAL      Los Angeles Lakers
# 2798     12024  1610612743               DEN          Denver Nuggets
# 2799     12024  1610612738               BOS          Boston Celtics
# 2800     12024  1610612762               UTA               Utah Jazz
# 2801     12024  1610612750               MIN  Minnesota Timberwolves
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# ...

# %%
df.to_csv('../data/fact_team_games.csv', index=False)
