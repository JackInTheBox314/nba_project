# %%
import nba_api.stats.endpoints as stats
import nba_api.stats.static.players as players

import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# Nikola Jokić
career = stats.playercareerstats.PlayerCareerStats(player_id='203999')
df = career.season_totals_regular_season.get_data_frame()

# %%
df.head()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
#
#    GP  GS   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0  80  55  1733  307   600   0.512    28    84    0.333  154  190   0.811
# 1  73  59  2038  494   854   0.578    45   139    0.324  188  228   0.825
# 2  75  73  2443  504  1010   0.499   111   280    0.396  266  313   0.850
# 3  80  80  2504  616  1206   0.511    83   270    0.307  289  352   0.821
# 4  73  73  2335  565  1071   0.528    80   255    0.314  246  301   0.817
#
#    OREB  DREB  REB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
help(stats)
stats.commonplayerinfo.CommonPlayerInfo(player_id='203999')
# Out:
# Help on package nba_api.stats.endpoints in nba_api.stats:
#
# NAME
#     nba_api.stats.endpoints
#
# PACKAGE CONTENTS
#     _base
#     _expected_data (package)
#     _parsers (package)
#     alltimeleadersgrids
#     assistleaders
#     assisttracker
#     boxscoreadvancedv2
#     boxscoreadvancedv3
#     boxscoredefensivev2
#     boxscorefourfactorsv2
#     boxscorefourfactorsv3
#     boxscorehustlev2
#     boxscorematchupsv3
#     boxscoremiscv2
#     boxscoremiscv3
#     boxscoreplayertrackv3
#     boxscorescoringv2
#     boxscorescoringv3
#     boxscoresummaryv2
#     boxscoresummaryv3
#     boxscoretraditionalv2
#     boxscoretraditionalv3
#     boxscoreusagev2
#     boxscoreusagev3
#     commonallplayers
#     commonplayerinfo
#     commonplayoffseries
#     commonteamroster
#     commonteamyears
#     cumestatsplayer
#     cumestatsplayergames
#     cumestatsteam
#     cumestatsteamgames
#     defensehub
#     draftboard
#     draftcombinedrillresults
# ...

# %%
all_players_info = players.get_players()
all_players_id =[d['id'] for d in all_players_info]
all_players_id
# Out:
# [76001,
#  76002,
#  76003,
#  51,
#  1505,
#  949,
#  76005,
#  76006,
#  76007,
#  203518,
#  1630173,
#  101165,
#  76008,
#  76009,
#  76010,
#  203112,
#  76011,
#  76012,
#  200801,
#  1629121,
#  203919,
#  149,
#  203500,
#  912,
#  1628389,
#  1629061,
#  76015,
#  202399,
#  201167,
#  1630534,
#  200772,
#  76016,
#  201336,
#  76017,
#  201582,
#  76018,
#  203006,
#  1629152,
#  202374,
#  76019,
#  76020,
#  1630583,
#  203128,
#  202332,
#  200746,
#  76021,
#  1626146,
#  724,
#  2042,
#  76022,
#  201570,
#  1629734,
#  1641725,
#  1630234,
#  2349,
#  1629638,
#  76024,
#  1628959,
#  76028,
#  1628960,
#  1628386,
#  706,
#  1628443,
#  202730,
#  76027,
#  2124,
#  76025,
#  951,
#  1641851,
#  2754,
#  76029,
#  200984,
#  76030,
#  201165,
#  308,
#  1747,
#  1824,
#  1630631,
#  680,
#  732,
#  202329,
#  200811,
#  76034,
#  2365,
#  2431,
#  101187,
#  202079,
#  76035,
#  76036,
#  1507,
#  76037,
#  944,
#  246,
#  202341,
#  76040,
#  1626147,
#  72,
# ...

# %%
active_players_info = players.get_active_players()
active_players_id =[d['id'] for d in active_players_info]
active_players_info
# Out:
# [{'id': 1630173,
#   'full_name': 'Precious Achiuwa',
#   'first_name': 'Precious',
#   'last_name': 'Achiuwa',
#   'is_active': True},
#  {'id': 203500,
#   'full_name': 'Steven Adams',
#   'first_name': 'Steven',
#   'last_name': 'Adams',
#   'is_active': True},
#  {'id': 1628389,
#   'full_name': 'Bam Adebayo',
#   'first_name': 'Bam',
#   'last_name': 'Adebayo',
#   'is_active': True},
#  {'id': 1630534,
#   'full_name': 'Ochai Agbaji',
#   'first_name': 'Ochai',
#   'last_name': 'Agbaji',
#   'is_active': True},
#  {'id': 1630583,
#   'full_name': 'Santi Aldama',
#   'first_name': 'Santi',
#   'last_name': 'Aldama',
#   'is_active': True},
#  {'id': 1641725,
#   'full_name': 'Trey Alexander',
#   'first_name': 'Trey',
#   'last_name': 'Alexander',
#   'is_active': True},
#  {'id': 1629638,
#   'full_name': 'Nickeil Alexander-Walker',
#   'first_name': 'Nickeil',
#   'last_name': 'Alexander-Walker',
#   'is_active': True},
#  {'id': 1628960,
#   'full_name': 'Grayson Allen',
# ...

# %%
career = stats.playercareerstats.PlayerCareerStats(player_id='1630173')
df = career.season_totals_regular_season.get_data_frame()
df.head()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1630173   2020-21        00  1610612748               MIA        21.0
# 1    1630173   2021-22        00  1610612761               TOR        22.0
# 2    1630173   2022-23        00  1610612761               TOR        23.0
# 3    1630173   2023-24        00  1610612761               TOR        24.0
# 4    1630173   2023-24        00  1610612752               NYK        24.0
#
#    GP  GS   MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0  61   4   737  124  228   0.544     0     1    0.000   56  110   0.509
# 1  73  28  1725  265  603   0.439    56   156    0.359   78  131   0.595
# 2  55  12  1141  196  404   0.485    29   108    0.269   87  124   0.702
# 3  25   0   437   78  170   0.459    13    47    0.277   24   42   0.571
# 4  49  18  1187  157  299   0.525    13    50    0.260   45   70   0.643
#
#    OREB  DREB  REB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
active_players_career_stats = []

for player_id in active_players_id:
    print(player_id)
    career = stats.playercareerstats.PlayerCareerStats(player_id=player_id)
    df = career.season_totals_regular_season.get_data_frame()
    print(df)
# Out:
# 1630173
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1630173   2020-21        00  1610612748               MIA        21.0
# 1    1630173   2021-22        00  1610612761               TOR        22.0
# 2    1630173   2022-23        00  1610612761               TOR        23.0
# 3    1630173   2023-24        00  1610612761               TOR        24.0
# 4    1630173   2023-24        00  1610612752               NYK        24.0
# 5    1630173   2023-24        00           0               TOT        24.0
# 6    1630173   2024-25        00  1610612752               NYK        25.0
# 7    1630173   2025-26        00  1610612758               SAC        26.0
#
#    GP  GS   MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0  61   4   737  124  228   0.544     0     1    0.000   56  110   0.509
# 1  73  28  1725  265  603   0.439    56   156    0.359   78  131   0.595
# ...
